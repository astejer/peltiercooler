# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def peltiergraphing(x, setpoint):
    
    coldntc=[] #in celsius
    hotntc=[] #in celsius
    digitaltemp=[] #in celsius
    time=[] #in milliseconds

    coldntc, hotntc, thirdntc, time = np.loadtxt(x, unpack=True)
    
    min1=min(coldntc)

    reftemp=[i*5 for i in range(-8,5)]
    reftime=[1556,1344,1166,1005,855,717,591,475,377,294,226,166,111]

    time1=[x/1000. for x in time]

    setpoint1=[setpoint] * (len(time))

    deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]
    deltat2=[abs(x-y) for x,y in zip(thirdntc,hotntc)]

    plt.figure(figsize=(15,10))
    plt.rcParams.update({'font.size': 18})
    plt.plot(time1, coldntc, label='Cold NTC Data', color='b', linewidth=3)
    plt.plot(time1, hotntc, label='Hot NTC Data', color='r', linewidth=3)
    plt.plot(time1, thirdntc, label='Third NTC Data', color='c', linewidth=3)
    plt.plot(time1, deltat1, label='$\Delta$T1', color='g', linewidth=3)
    plt.plot(time1, deltat2, label='$\Delta$T2', color='k', linewidth=3)
    plt.plot(time1, setpoint1, label='Setpoint = setpoint $\degree$C', color='C1', linewidth=3)
    plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')

    deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]
    #plt.xlim(200,600)
    #plt.ylim(-.25,.2)
    plt.ylabel('Temperature ($\degree$C)')
    plt.xlabel('Time (seconds)')
    plt.title('Title')
    plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

    return plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


coldntc=[] #in celsius
hotntc=[] #in celsius
digitaltemp=[] #in celsius
time=[] #in milliseconds


coldntc, hotntc, thirdntc, time = np.loadtxt('sim2.dat', unpack=True)

time1=[x/1000. for x in time]
setpoint=[-17.73] * (len(time))

deltat=[abs(x-y) for x,y in zip(coldntc,hotntc)]

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 16})
plt.plot(time1, coldntc, label='Cold NTC Data', color='b', linewidth=3)
plt.plot(time1, hotntc, label='Hot NTC Data', color='r', linewidth=3)
plt.plot(time1, thirdntc, label='Third NTC Data', color='c', linewidth=3)
plt.plot(time1, deltat, label='$\Delta$T', color='g', linewidth=3)
plt.plot(time1, setpoint, label='Min Temp = -17.73$\degree$C', color='C1', linewidth=3)
plt.xlim(0,2100)

deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]
#plt.xlim(200,600)
#plt.ylim(-.25,.2)
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=5)
plt.title('Two Peltiers Powered by two MOSFETs simultaneously (15.4V/7A and 9V/6A)')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


coldntc=[] #in celsius
hotntc=[] #in celsius
digitaltemp=[] #in celsius
time=[] #in milliseconds


coldntc, hotntc, thirdntc, time = np.loadtxt('sim3.dat', unpack=True)


reftemp=[i*5 for i in range(-8,5)]
reftime=[1556,1344,1166,1005,855,717,591,475,377,294,226,166,111]


time1=[x/1000. for x in time]

setpoint=[-27.07] * (len(time))

deltat=[abs(x-y) for x,y in zip(coldntc,hotntc)]

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, coldntc, label='Cold NTC Data', color='b', linewidth=3)
plt.plot(time1, hotntc, label='Hot NTC Data', color='r', linewidth=3)
plt.plot(time1, thirdntc, label='Third NTC Data', color='c', linewidth=3)
plt.plot(time1, deltat, label='$\Delta$T', color='g', linewidth=3)
plt.plot(time1, setpoint, label='Min Temp = -27.07$\degree$C', color='C1', linewidth=3)
plt.plot(reftime,reftemp)
plt.xlim(0,2100)


deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]
#plt.xlim(200,600)
#plt.ylim(-.25,.2)
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=5)
plt.title('Two Peltiers Powered by two MOSFETs simultaneously (15.4V/7A and 5V/3A)')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


coldntc=[] #in celsius
hotntc=[] #in celsius
digitaltemp=[] #in celsius
time=[] #in milliseconds


coldntc, hotntc, thirdntc, time = np.loadtxt('sim4.dat', unpack=True)


reftemp=[i*5 for i in range(-8,5)]
reftime=[1556,1344,1166,1005,855,717,591,475,377,294,226,166,111]


time1=[x/1000. for x in time]

setpoint=[-27.28] * (len(time))

deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]
deltat2=[abs(x-y) for x,y in zip(thirdntc,hotntc)]

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, coldntc, label='Cold NTC Data', color='b', linewidth=3)
plt.plot(time1, hotntc, label='Hot NTC Data', color='r', linewidth=3)
plt.plot(time1, thirdntc, label='Third NTC Data', color='c', linewidth=3)
plt.plot(time1, deltat1, label='$\Delta$T1', color='g', linewidth=3)
plt.plot(time1, deltat2, label='$\Delta$T2', color='k', linewidth=3)
plt.plot(time1, setpoint, label='Min Temp = -28.81$\degree$C', color='C1', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')

deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]
#plt.xlim(200,600)
#plt.ylim(-.25,.2)
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Two Peltiers Powered by two MOSFETs simultaneously (15.4V/7A and 4V/3A)')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=5)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def peltiergraphing(x):
    
    coldntc=[] #in celsius
    hotntc=[] #in celsius
    digitaltemp=[] #in celsius
    time=[] #in milliseconds

    coldntc, hotntc, thirdntc, time = np.loadtxt(x, unpack=True)

    reftemp=[i*5 for i in range(-8,5)]
    reftime=[1556,1344,1166,1005,855,717,591,475,377,294,226,166,111]

    time1=[x/1000. for x in time]

    setpoint=[-27.71] * (len(time))

    deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]
    deltat2=[abs(x-y) for x,y in zip(thirdntc,hotntc)]

    plt.figure(figsize=(15,10))
    plt.rcParams.update({'font.size': 18})
    plt.plot(time1, coldntc, label='Cold NTC Data', color='b', linewidth=3)
    plt.plot(time1, hotntc, label='Hot NTC Data', color='r', linewidth=3)
    plt.plot(time1, thirdntc, label='Third NTC Data', color='c', linewidth=3)
    plt.plot(time1, deltat1, label='$\Delta$T1', color='g', linewidth=3)
    plt.plot(time1, deltat2, label='$\Delta$T2', color='k', linewidth=3)
    plt.plot(time1, setpoint, label='Min Temp = -28.81$\degree$C', color='C1', linewidth=3)
    plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')

    deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]
    #plt.xlim(200,600)
    #plt.ylim(-.25,.2)
    plt.ylabel('Temperature ($\degree$C)')
    plt.xlabel('Time (seconds)')
    plt.title('Two Peltiers Powered by two MOSFETs simultaneously (15.4V/7A and 4V/3A)')
    plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

    return plt.show()
peltiergraphing('sim4.dat')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


coldntc=[] #in celsius
hotntc=[] #in celsius
digitaltemp=[] #in celsius
time=[] #in milliseconds


coldntc, hotntc, thirdntc, time = np.loadtxt('5v4a-30c.dat', unpack=True)


reftemp=[i*5 for i in range(-8,5)]
reftime=[1556,1344,1166,1005,855,717,591,475,377,294,226,166,111]


time1=[x/1000. for x in time]

setpoint=[-30.89] * (len(time))

deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]
deltat2=[abs(x-y) for x,y in zip(thirdntc,hotntc)]

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, coldntc, label='Cold NTC Data', color='b', linewidth=3)
plt.plot(time1, hotntc, label='Hot NTC Data', color='r', linewidth=3)
plt.plot(time1, thirdntc, label='Third NTC Data', color='c', linewidth=3)
plt.plot(time1, deltat1, label='$\Delta$T1', color='g', linewidth=3)
plt.plot(time1, deltat2, label='$\Delta$T2', color='k', linewidth=3)
plt.plot(time1, setpoint, label='Min Temp = -28.81$\degree$C', color='C1', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')

deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]
#plt.xlim(200,600)
#plt.ylim(-.25,.2)
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Two Peltiers Powered by two MOSFETs simultaneously (15.4V/7A and 4V/3A)')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.show()

# %%
peltiergraphing('newplate1.dat', -28.81)

# %%
peltiergraphing('platenoins.dat',-25.83)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

coldntc=[] #in celsius
hotntc=[] #in celsius
digitaltemp=[] #in celsius
time=[] #in milliseconds

coldntc, hotntc, thirdntc, time = np.loadtxt("calibration1.dat", unpack=True)
    
min1=min(coldntc)

reftemp=[i*5 for i in range(-8,5)]
reftime=[1556,1344,1166,1005,855,717,591,475,377,294,226,166,111]

time1=[x/1000. for x in time]

x=np.linspace(0,1000)

deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]
deltat2=[abs(x-y) for x,y in zip(thirdntc,hotntc)]

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, coldntc, label='Cold NTC Data', color='b', linewidth=3)
plt.plot(time1, hotntc, label='Hot NTC Data', color='r', linewidth=3)
plt.plot(time1, thirdntc, label='Third NTC Data', color='c', linewidth=3)
plt.plot(time1, deltat1, label='$\Delta$T1', color='g', linewidth=3)
plt.plot(time1, deltat2, label='$\Delta$T2', color='k', linewidth=3)




deltat1=[abs(x-y) for x,y in zip(coldntc,hotntc)]

plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Title')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.show()

# %%
peltiergraphing('c.dat',-30.42)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

    
oldntc=[] #in celsius
newntc=[] #in celsius
newptc=[] #in celsius
lm35cz=[] #in celsius
onewire=[] #in celsius
time=[] #in milliseconds

oldntc, newntc, newptc, lm35cz, onewire, time = np.loadtxt("tempdata.dat", unpack=True)

reftemp=[-41, -40, -35, -30, -25, -20, -15, -10, -5, 0.1, 5, 10, 15, 20, 22.7]
reftime=[2950,2563,2126,1777,1483,1233,1021,837,685,565,440,336,235,140,0.1]

time1=[x/1000. for x in time]

setpoint1=[5.] * (len(time))

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, oldntc, label='Old NTC Data', color='r', linewidth=3)
plt.plot(time1, newntc, label='New NTC Data', color='g', linewidth=3)
plt.plot(time1, newptc, label='New PTC Data', color='b', linewidth=3)
plt.plot(time1, lm35cz, label='IC Sensor Data', color='y', linewidth=3)
plt.plot(time1, onewire, label='OneWire Data', color='c', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, oldntc, label='Old NTC Data', color='r', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=2)

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, newntc, label='New NTC Data', color='g', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, newptc, label='New PTC Data', color='b', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, lm35cz, label='IC Sensor Data', color='y', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, onewire, label='OneWire Data', color='c', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)


plt.show()

# %%
plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, oldntc, label='Old NTC Data', color='r', linewidth=3)
plt.plot(time1, newntc, label='New NTC Data', color='g', linewidth=3)
plt.plot(time1, newptc, label='New PTC Data', color='b', linewidth=3)
plt.plot(time1, lm35cz, label='IC Sensor Data', color='y', linewidth=3)
plt.plot(time1, onewire, label='OneWire Data', color='c', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, oldntc, label='Old NTC Data', color='r', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=2)

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, newntc, label='New NTC Data', color='g', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, newptc, label='New PTC Data', color='b', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, lm35cz, label='IC Sensor Data', color='y', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 18})
plt.plot(time1, onewire, label='OneWire Data', color='c', linewidth=3)
plt.plot(reftime,reftemp, 'm--', linewidth=3, label='Climate Chamber')
plt.ylabel('Temperature ($\degree$C)')
plt.xlabel('Time (seconds)')
plt.title('Temperature Sensor Comparison')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=3)


plt.show()
